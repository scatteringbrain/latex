# %%
10^(-11)
# Out:
# -1

# %%
pow(10,-11)
# Out:
# 1e-11

# %%
a = 6.58 * pow(10,-22) * 3 * pow(10,8)

# %%
b = 2 * pow(10,-15)

# %%
pow(a/b,2)
# Out:
# 9741.689999999997

# %%
pow(0.511,2)
# Out:
# 0.261121

# %%
import math
math.sqrt(9740+0.261)
# Out:
# 98.69276062609659

# %%
G= 6.67*pow(10,-11)
m_e = 9.1*pow(10,-31)
k = 8.98*pow(10,9)
q_e = 1.6*pow(10,-19)

# %%
(G*pow(m_e,2))/(k*pow(q_e,2))
# Out:
# 2.402659990952115e-43
